# %% [markdown]
# <a href="https://colab.research.google.com/github/EmilioUcelayLojo/AA3/blob/laboratorios_practicas/lab6/lab6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/eirasf/GCED-AA3/blob/main/lab6/lab6.ipynb)
#
# # Lab6: Aprendizaje por refuerzo - Métodos de Temporal Difference
#
# En este laboratorio seguiremos explorando métodos tabulares de aprendizaje por refuerzo que no necesitan disponer de un modelo. En particular, estudiaremos los métodos de **Temporal Difference**.
#
# Para explorar estos métodos volveremos a utilizar [Gym](https://www.gymlibrary.dev/) con un entorno GridWorld, es decir, un tablero con casillas por las que se mueve el agente, tal como hicimos en el Lab4. En particular, vamos a utilizar el entorno `MiniGrid-DistShift1-v0`. En este entorno el agente deberá llegar hasta la meta, pero esta vez evitando caer en la lava, que hace que se termine el episodio con recompensa 0.
#
# Carguemos el entorno y explorémoslo brevemente.

# %%
# Si los paquetes no están instalados, hay que ejecutar estas líneas:
# !pip install gymnasium[classic-control]
# !pip install minigrid
import gymnasium as gym
import minigrid
import numpy as np
env = gym.make('MiniGrid-DistShift1-v0', render_mode='rgb_array')

import matplotlib.pyplot as plt

# TODO - Muestra el entorno para ver cómo es el tablero. Para ello, recupera la función muestra_entorno del lab4 y lánzala

env.reset()

def muestra_entorno(env:gym.Env) -> None:
    im = plt.imshow(env.render())
    plt.show()

muestra_entorno(env)
# Out:
# Requirement already satisfied: gymnasium[classic-control] in /usr/local/lib/python3.11/dist-packages (1.1.1)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.11/dist-packages (from gymnasium[classic-control]) (2.0.2)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from gymnasium[classic-control]) (3.1.1)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.11/dist-packages (from gymnasium[classic-control]) (4.12.2)
# Requirement already satisfied: farama-notifications>=0.0.1 in /usr/local/lib/python3.11/dist-packages (from gymnasium[classic-control]) (0.0.4)
# Requirement already satisfied: pygame>=2.1.3 in /usr/local/lib/python3.11/dist-packages (from gymnasium[classic-control]) (2.6.1)
# Collecting minigrid
#   Downloading minigrid-3.0.0-py3-none-any.whl.metadata (6.7 kB)
# Requirement already satisfied: numpy>=1.18.0 in /usr/local/lib/python3.11/dist-packages (from minigrid) (2.0.2)
# Requirement already satisfied: gymnasium>=0.28.1 in /usr/local/lib/python3.11/dist-packages (from minigrid) (1.1.1)
# Requirement already satisfied: pygame>=2.4.0 in /usr/local/lib/python3.11/dist-packages (from minigrid) (2.6.1)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from gymnasium>=0.28.1->minigrid) (3.1.1)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.11/dist-packages (from gymnasium>=0.28.1->minigrid) (4.12.2)
# Requirement already satisfied: farama-notifications>=0.0.1 in /usr/local/lib/python3.11/dist-packages (from gymnasium>=0.28.1->minigrid) (0.0.4)
# Downloading minigrid-3.0.0-py3-none-any.whl (136 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 136.7/136.7 kB 3.0 MB/s eta 0:00:00
# Installing collected packages: minigrid
# Successfully installed minigrid-3.0.0

# %%
# TODO - Anotar las dimensiones del tablero para poder utilizarlas después
NUM_COLUMNAS = 7  # El tablero tiene 7 columnas
NUM_FILAS = 5  # El tablero tiene 5 filas
NUM_ORIENTACIONES = 4


# Muestra las acciones disponibles
acciones = env.get_wrapper_attr('actions')
print([a.name for a in acciones])

# Las acciones son las mismas que en el laboratorio 4. Nos quedaremos de nuevo solo con LEFT, RIGHT y FORWARD
# acciones = env.actions  # Esta línea causa el error
num_acciones = env.action_space.n # Obtener el número total de acciones

# Seleccionamos solo las tres acciones indicadas
# ACCIONES_UTILES = [acciones.left, acciones.right, acciones.forward] # Esta línea también necesita modificarse
ACCIONES_UTILES = [0, 1, 2] # Asumiendo que left, right, forward son las acciones 0, 1, 2
NUM_ACCIONES = len(ACCIONES_UTILES)

print(num_acciones)
print(ACCIONES_UTILES)
# Out:
# ['left', 'right', 'forward', 'pickup', 'drop', 'toggle', 'done']
# 7
# [0, 1, 2]

# %% [markdown]
# Comprueba el efecto de caer en la lava. El episodio debería terminarse y recibiendo el agente una recompensa de 0.

# %%
#TODO - Efectúa dos acciones para que el agente caiga en la lava y verifica que se recibe una recompensa de 0
obs, reward, terminated, truncated, info = env.step(2)  # Avanzar un paso
obs, reward, terminated, truncated, info = env.step(2)
#COMPROBACIONES
assert(reward==0)
assert(terminated)
_ = env.reset()

# %% [markdown]
# # Obtención de políticas óptimas
#
# ## Métodos de Temporal Difference
#
# Los métodos basados en **Temporal Difference**, al igual que los métodos Montecarlo, carecen de información respecto a cómo funciona el modelo (no conocen $p(s',r | s,a)$). Por ello, también deben interactuar con el entorno para obtener muestras con las que después hacer estimaciones.
#
# A diferencia de los métodos Montecarlo, los métodos de Temporal Difference no esperan a terminar un episodio para actualizar los valores de los estados transitados. En su lugar, los métodos Temporal Difference aprovechan la idea de que el valor $v(S)$ de un estado $S$ tiene relación con el valor de los estados $S'$ a los que se puede llegar desde $S$. Dicho de otra manera, los estados que pueden conducir a un estado malo serán también malos (y viceversa). Esta idea está codificada en las **ecuaciones de Bellman**:
#
# $$v_\pi(s)=\sum_{a}\pi(a|s)\sum_{s',r} p(s',r | s,a)\left[r + \gamma v_\pi(s')\right]$$
#
# La misma idea se puede aplicar a la hora de estimar el valor de ejecutar la acción $a$ estando en el estado $s$. Las acciones $a$ que lleven a estados $s'$ cuyas acciones tengan valores altos tendrán, a su vez, valores altos (y viceversa).
#
# $$q_\pi(s,a)=\sum_{s',r} p(s',r | s,a)\left[r + \gamma \sum_{a'}\pi(a'|s')q_\pi(s',a')\right]$$
#
# Aplicar esta idea nos permitirá hacer *bootstrapping* en nuestros cálculos: a la hora de calcular el valor de un estado podremos aprovechar la aproximación que tenemos para estados adyacentes.
#
# ### SARSA
# El primer método que probaremos es SARSA. Este algoritmo se denomina así por las variables involucradas en cada paso de actualización de la estimación de $Q(S,A)$. Las variables son $S_t,A_t,R_{t+1},S_{t+1},A_{t+1}$ y la actualización utiliza esta fórmula:
#
# $$Q(S_t,A_t) \leftarrow Q(S_t,A_t) + \alpha [R_{t+1} + \gamma Q(S_{t+1},A_{t+1}) - Q(S_t,A_t)]$$
#
# El algoritmo ejecutará repetidos episodios (potencialmente infinitos; es un algoritmo de control y el agente podría seguirlo utilizando durante toda su existencia) y, para cada paso del episodio hará la actualización según la fórmula indicada arriba. Esto requiere que haya decidido la siguiente acción a tomar ($A_{t+1}$) antes de actualizar el valor de la acción anterior ($A_t$).
#
# ![Sarsa](https://github.com/eirasf/GCED-AA3/blob/main/lab6/img/sarsa.png?raw=1)
#
# Para facilitar la implementación, vamos primero a escribir un par de funciones auxiliares que nos permitan representar estados y muestrear acciones a partir de $Q$.

# %%
from collections import namedtuple

GAMMA = 0.9  # Para este problema vamos a utilizar un factor de descuento de 0.9, es decir, las recompensas futuras se descontarán un 10% por cada paso que sea necesario para obtenerlas.

env.max_steps = 5000  # Fijamos el número máximo de acciones por episodio a 5000, para permitir episodios largos

# FUNCIONES AUXILIARES
# TODO - Recupera la función get_estado del laboratorio 4. Esta función codifica el estado del entorno en una lista de tres elementos: columna, fila, orientación

Estado = namedtuple('Estado', ['x', 'y', 'dir'])

def get_estado(env: gym.Env) -> Estado:
    """
    Obtiene el estado actual del entorno.

    Args:
        env: El entorno de Gym.

    Returns:
        Un objeto Estado que representa el estado actual del entorno.
    """
    # Obtener la posición y dirección del agente
    pos = env.get_wrapper_attr('agent_pos')
    direccion = env.get_wrapper_attr('agent_dir')

    # Adaptar la posición a la numeración del enunciado (empezando en 0)
    x = pos[0]-1
    y = pos[1]-1

    # Crear y devolver el Estado
    return Estado(x, y, direccion)
# COMPROBACIÓN
env.reset()
estado_actual = get_estado(env)
assert estado_actual.x == 0, f'El estado inmediatamente después de resetear debe indicar x=0 y el tuyo indica {estado_actual.x}'
assert estado_actual.y == 0, f'El estado inmediatamente después de resetear debe indicar y=0 y el tuyo indica {estado_actual.y}'
assert estado_actual.dir == 0, f'El estado inmediatamente después de resetear debe indicar dir=0 y el tuyo indica {estado_actual.dir}'

# TODO - Escribe una función que dados los valores q de las distintas acciones en un estado concreto, devuelva una acción haciendo una selección epsilon-greedy a partir de los q_valores.
def get_accion_epsilon_greedy(q_valores: np.ndarray, epsilon: float):
    '''
    Selecciona una acción basándose en los q_values proporcionados. Una fracción de las veces (indicada por epsilon) devolverá una acción al azar

    Argumentos:
    q_values -- Lista con los q valores de las acciones entre las que seleccionar.
    epsilon -- Fracción de las veces que se devolverá una acción al azar
    '''
    if np.random.random() < epsilon:
        # Devuelve una acción al azar
        return np.random.choice(len(q_valores))
    # Devuelve el índice del mayor q valor
    return np.argmax(q_valores)


# COMPROBACIÓN
assert(get_accion_epsilon_greedy([1,2,4],0)==2)

# %% [markdown]
# Para algoritmos derivados de SARSA haremos _exploring starts_, es decir, comienzarán cada vez en un estado al azar. Esto facilita la exploración y, por tanto, el entrenamiento ya que facilita que se den episodios que el agente sea capaz de resolver incluso con una política aleatoria.
#
# Deberemos crear funciones que nos permitan llevar esto a cabo.

# %%
# TODO - Escribe una función que genere la codificación para un estado válido al azar. Devolverá una lista con tres valores que indiquen columna, fila y orientación
def get_estado_aleatorio() -> Estado:
    """
    Genera un estado aleatorio válido.

    Returns:
        Un objeto Estado con valores aleatorios para x, y y dir.
    """
    # Genera valores aleatorios para x, y y dir dentro de los rangos permitidos
    x = np.random.randint(0, NUM_COLUMNAS)  # columna
    y = np.random.randint(0, NUM_FILAS)  # fila
    direccion = np.random.randint(0, NUM_ORIENTACIONES)  # orientación

    return Estado(x, y, direccion)


# TODO - Escribe una función que establezca el entorno para que coincida con lo indicado por un estado dado
def set_estado(env: gym.Env, estado: Estado):
    """
    Establece el entorno al estado especificado.

    Args:
        env: El entorno de Gym.
        estado: El objeto Estado que define el estado deseado.
    """
    # Establece la posición del agente
    env.unwrapped.agent_pos = (estado.x , estado.y )
    # Establece la dirección del agente
    env.unwrapped.agent_dir = estado.dir


# COMPROBACIÓN
env.reset()
muestra_entorno(env) # Debe mostrar al agente en la casilla 0,0
set_estado(env, Estado(x=2, y=3, dir=0))
muestra_entorno(env) # Debe mostrar al agente en la casilla 2,3

# %% [markdown]
# Ya tenemos lo necesario para implementar SARSA. Vamos a establecer un número fijo de iteraciones y hacer que devuelva los valores $Q$ al terminar. Además, incluiremos mensajes al terminar cada episodio que indiquen:
#  - El número de episodio que se ha finalizado
#  - La recompensa obtenida
#  - El número de acciones necesarias para completar el episodio
#  - La recompensa media obtenida durante los últimos 100 episodios (si se han ejecutado al menos 100)

# %%
def sarsa(num_episodios: int = 500, ALPHA: float = 0.1, EPSILON: float = 0.25) -> np.ndarray:
    # TODO - Inicializa los valores Q a cero con el shape adecuado
    q_valores = np.zeros((NUM_COLUMNAS, NUM_FILAS, NUM_ORIENTACIONES, NUM_ACCIONES))

    # En ultimos100retornos almacenaremos los retornos de los últimos 100 episodios
    ultimos100retornos = []
    # TODO - Haz tantos episodios como indica num_episodes
    for i in range(num_episodios):
        # TODO - Devuelve el entorno a su estado inicial
        env.reset()
        # TODO - Initialize S
        estado_actual = get_estado(env)
        # TODO - Choose A from S using policy derived from Q (e.g. epsilon-greedy)
        accion_actual = get_accion_epsilon_greedy(q_valores[estado_actual.x, estado_actual.y, estado_actual.dir], EPSILON)

        retorno = 0
        num_pasos = 0
        # TODO - Loop for each step of episode (repite hasta que el episodio termine)
        completado = False
        while not completado:
            num_pasos += 1
            # TODO - Take action A, observe R, S'
            obs, reward, completado, truncado, info = env.step(ACCIONES_UTILES[accion_actual])
            estado_siguiente = get_estado(env)

            # TODO - Acumula la recompensa R a returns para poder imprimir el retorno del episodio
            retorno += reward
            # TODO - Choose A' from S' using policy derived from Q (e.g. epsilon-greedy)
            accion_siguiente = get_accion_epsilon_greedy(q_valores[estado_siguiente.x, estado_siguiente.y, estado_siguiente.dir], EPSILON)
            # TODO - Q(S,A) <- Q(S,A) + ALPHA * [R + GAMMA * Q(S',A') - Q(S,A)]
            q_valores[estado_actual.x, estado_actual.y, estado_actual.dir, accion_actual] += ALPHA * (reward + GAMMA * q_valores[estado_siguiente.x, estado_siguiente.y, estado_siguiente.dir, accion_siguiente] - q_valores[estado_actual.x, estado_actual.y, estado_actual.dir, accion_actual])
            # TODO - S <- S'; A <- A'
            estado_actual = estado_siguiente
            accion_actual = accion_siguiente

        # Tras terminar el episodio almacenamos el retorno en los 100 últimos...
        ultimos100retornos.append(retorno)
        string_retornos100 = ''
        if len(ultimos100retornos) == 101:  # ... y si hay ya más de 100...
            ultimos100retornos.pop(0)  # ...quitamos el más antiguo (para tener siempre 100, no más)...
            # ... y preparamos el mensaje para mostrar la media de los retornos
            string_retornos100 = f'(retorno medio de {np.mean(ultimos100retornos)} en los últimos 100 episodios)'
        # Mostramos el mensaje tras cada episodio
        print(f'Terminado episodio {i} con retorno {retorno} en {num_pasos} pasos {string_retornos100}')

    return q_valores

# %% [markdown]
# El proceso de aprendizaje tiene una componente aleatoria importante, por lo que dos ejecuciones consecutivas pueden aprender valores $Q$ diferentes de las que se deriven políticas $\pi$ también diferentes. No obstante, si has implementado bien el algoritmo, deberías haber observado lo siguiente:
#   1. Inicialmente hay muchos episodios con retorno 0 (el agente acaba en la lava). La duración de estos episodios es muy variable. Además, si imprimiésemos `q_values` tras cada uno de estos episodios, ¡veríamos que $Q$ no se modifica! Cada paso utiliza $R$ y $Q(S',A')$ para actualizar $Q(S,A)$, pero si tanto $R$ como $Q(S',A')$ son cero, el valor de $Q(S,A)$ no cambiará.
#   1. Con el tiempo, y por pura casualidad, el agente terminará algún episodio llegando a la meta. Esto le reportará una recompensa de 1, lo que hará que $Q(S_t,A_t)$ se actualice a un valor positivo.
#   1. La próxima vez que el agente esté en $S_t$, elegirá la acción $A_t$ (salvo que toque acción aleatoria por el $\epsilon$), lo que hará que termine el episodio con recompensa 1. **¡Habrá aprendido una política útil para la última casilla!** Pero, además, el estado $S_{t-1}$ que llevó a $S_t$ (usando la acción $A_{t-1}$) verá su $Q(S_{t-1},A_{t-1})$ actualizado a un valor positivo. **¡Ya sabrá una política útil para las dos últimas casillas!**
#   1. Mediante este proceso, la información respecto a qué política es útil se irá propagando desde las casillas aledañas a la meta a sus vecinas, y de estas a sus vecinas y así sucesivamente hasta cubrir el tablero entero. A esto hay que añadir que, también por pura casualidad, el agente puede encontrar otros caminos que conducen a la meta y lanzar este mismo proceso de propagación pero siguiendo otro camino que conduzca a la meta.
#   1. El efecto de esto es que, a medida que transcurren los episodios ocurren dos cosas:
#     - El número de episodios con retorno positivo aumenta
#     - La duración de los episodios con retorno positivos disminuye (el agente va más tiempo por "camino conocido")
#   1. Esto repercute en el retorno medio de los 100 últimos episodios: comenzará siendo minúsculo, pero llegado un punto subirá con gran velocidad.
#   1. El retorno de los últimos 100 episodios alcanzará un punto máximo en torno al cual oscilará hacia el final.
#
#
# Visualicemos la política aprendida. Vamos a mostrar, para cada casilla, la orientación que tiene el agente cuando la acción preferida (la que tiene mayor valor $Q$) sea `FORWARD`.
#
# >**Recordatorio**
# >
# > Las orientaciones se codifican así:
# > - 0 $\rightarrow$ derecha
# > - 1 $\rightarrow$ abajo
# > - 2 $\rightarrow$ izquierda
# > - 3 $\rightarrow$ arriba

# %%
# Esta función devuelve un carácter de flecha que representa la orientación del agente para la cual los q valores recomiendan la acción forward
def get_flecha_direccion_maximo_valor(q_values:np.ndarray) -> str:
    accion_preferida_por_orientacion = q_values.argmax(axis=1) # Para cada una de las cuatro orientaciones, calculamos qué acción se prefiere
    direccion = np.argmax(accion_preferida_por_orientacion == 2) # De las orientaciones que prefieran FORWARD, tomamos una (la primera)
    # En función de la orientación, devolvemos la flecha apropiada.
    if direccion==0:
        return '⮕'
    if direccion==1:
        return '⬇'
    if direccion==2:
        return '⬅'
    if direccion==3:
        return '⬆'
    return '?'

# Muestra la política por pantalla
def dibuja_politica(q_valores:np.ndarray) -> None:
    # Recorre las filas del tablero...
    for i in range(q_valores.shape[1]):
        # ... componiendo una línea por fila...
        linea = ''
        for j in range(q_valores.shape[0]): # Recorre las columnas
            if i==0 and j==6: # Pintamos la meta
                    linea+='🟥'
            elif (i==0 or i==1)and j>1 and j<5: # Pintamos la lava
                    linea+='🟧'
            else:
                linea+=get_flecha_direccion_maximo_valor(q_valores[j,i]) # Pintamos la flecha apropiada para esta casilla
        # ...que finalmente imprime
        print(linea)

# TODO - Muestra la política que se deriva de los valores aprendidos por SARSA
q_valores_sarsa = sarsa()
dibuja_politica(q_valores_sarsa)
# Out:
# Terminado episodio 0 con retorno 0 en 32 pasos
# Terminado episodio 1 con retorno 0 en 22 pasos
# Terminado episodio 2 con retorno 0 en 528 pasos
# Terminado episodio 3 con retorno 0 en 71 pasos
# Terminado episodio 4 con retorno 0 en 332 pasos
con retorno 0 en 2 pasos (retorno medio de 0.0 en los últimos 100 episodios)
# Terminado episodio 482 con retorno 0 en 10 pasos (retorno medio de 0.0 en los últimos 100 episodios)
# Terminado episodio 483 con retorno 0 en 100 pasos (retorno medio de 0.0 en los últimos 100 episodios)
# Terminado episodio 484 con retorno 0 en 6 pasos (retorno medio de 0.0 en los últimos 100 episodios)
# Terminado episodio 485 con retorno 0 en 37 pasos (retorno medio de 0.0 en los últimos 100 episodios)
# Terminado episodio 486 con retorno 0 en 193 pasos (retorno medio de 0.0 en los últimos 100 episodios)
# Terminado episodio 487 con retorno 0 en 81 pasos (retorno medio de 0.0 en los últimos 100 episodios)
# Terminado episodio 488 con retorno 0 en 2 pasos (retorno medio de 0.0 en los últimos 100 episodios)
# Terminado episodio 489 con retorno 0 en 2 pasos (retorno medio de 0.0 en los últimos 100 episodios)
# Terminado episodio 490 con retorno 0 en 6 pasos (retorno medio de 0.0 en los últimos 100 episodios)
# Terminado episodio 491 con retorno 0 en 2 pasos (retorno medio de 0.0 en los últimos 100 episodios)
# Terminado episodio 492 con retorno 0 en 4 pasos (retorno medio de 0.0 en los últimos 100 episodios)
# Terminado episodio 493 con retorno 0 en 6 pasos (retorno medio de 0.0 en los últimos 100 episodios)
# Terminado episodio 494 con retorno 0 en 2 pasos (retorno medio de 0.0 en los últimos 100 episodios)
# Terminado episodio 495 con retorno 0 en 4 pasos (retorno medio de 0.0 en los últimos 100 episodios)
# Terminado episodio 496 con retorno 0 en 2 pasos (retorno medio de 0.0 en los últimos 100 episodios)
# Terminado episodio 497 con retorno 0 en 2 pasos (retorno medio de 0.0 en los últimos 100 episodios)
# Terminado episodio 498 con retorno 0 en 4 pasos (retorno medio de 0.0 en los últimos 100 episodios)
# Terminado episodio 499 con retorno 0 en 27 pasos (retorno medio de 0.0 en los últimos 100 episodios)
# ⮕⮕🟧🟧🟧⮕🟥
# ⮕⬇🟧🟧🟧⮕⬇
# ⮕⬇⬇⬆⬆⬅⮕
# ⮕⬅⮕⬇⬅⬅⬅
# ⬆⬆⬅⬅⬅⬆⬇

# %% [markdown]
# Hemos comprobado que nuestro agente tiene que hacer muchos episodios que no le llevan a aprender porque no le dan ninguna recompensa, lo cual provoca que no pueda actualizar $Q(S,A)$ para ninguno de los pares $S,A$ por los que transita.
#
# **¿Qué crees que ocurriría si diésemos una recompensa negativa a caer en la lava? ¿Cambiaría la velocidad a la que aprende el agente?**
#
# Haz la prueba añadiendo esto después de cada paso:
# ```python
#     if completado and reward==0:
#         reward = -1
# ```
#
# Modifica la función `sarsa` y ejecuta la celda siguiente. **¿Qué observas?**

# %%
def sarsa(num_episodios: int = 500, ALPHA: float = 0.1, EPSILON: float = 0.25) -> np.ndarray:
    # TODO - Inicializa los valores Q a cero con el shape adecuado
    q_valores = np.zeros((NUM_COLUMNAS, NUM_FILAS, NUM_ORIENTACIONES, NUM_ACCIONES))

    # En ultimos100retornos almacenaremos los retornos de los últimos 100 episodios
    ultimos100retornos = []
    # TODO - Haz tantos episodios como indica num_episodes
    for i in range(num_episodios):
        # TODO - Devuelve el entorno a su estado inicial
        env.reset()
        # TODO - Initialize S
        estado_actual = get_estado(env)
        # TODO - Choose A from S using policy derived from Q (e.g. epsilon-greedy)
        accion_actual = get_accion_epsilon_greedy(q_valores[estado_actual.x, estado_actual.y, estado_actual.dir], EPSILON)

        retorno = 0
        num_pasos = 0
        # TODO - Loop for each step of episode (repite hasta que el episodio termine)
        completado = False
        while not completado:
            num_pasos += 1
            # TODO - Take action A, observe R, S'
            obs, reward, completado, truncado, info = env.step(ACCIONES_UTILES[accion_actual])
            estado_siguiente = get_estado(env)

             # Añadimos la condición para penalizar caer en la lava
            if completado and reward == 0:
                reward = -1

            # TODO - Acumula la recompensa R a returns para poder imprimir el retorno del episodio
            retorno += reward
            # TODO - Choose A' from S' using policy derived from Q (e.g. epsilon-greedy)
            accion_siguiente = get_accion_epsilon_greedy(q_valores[estado_siguiente.x, estado_siguiente.y, estado_siguiente.dir], EPSILON)
            # TODO - Q(S,A) <- Q(S,A) + ALPHA * [R + GAMMA * Q(S',A') - Q(S,A)]
            q_valores[estado_actual.x, estado_actual.y, estado_actual.dir, accion_actual] += ALPHA * (reward + GAMMA * q_valores[estado_siguiente.x, estado_siguiente.y, estado_siguiente.dir, accion_siguiente] - q_valores[estado_actual.x, estado_actual.y, estado_actual.dir, accion_actual])
            # TODO - S <- S'; A <- A'
            estado_actual = estado_siguiente
            accion_actual = accion_siguiente

        # Tras terminar el episodio almacenamos el retorno en los 100 últimos...
        ultimos100retornos.append(retorno)
        string_retornos100 = ''
        if len(ultimos100retornos) == 101:  # ... y si hay ya más de 100...
            ultimos100retornos.pop(0)  # ...quitamos el más antiguo (para tener siempre 100, no más)...
            # ... y preparamos el mensaje para mostrar la media de los retornos
            string_retornos100 = f'(retorno medio de {np.mean(ultimos100retornos)} en los últimos 100 episodios)'
        # Mostramos el mensaje tras cada episodio
        print(f'Terminado episodio {i} con retorno {retorno} en {num_pasos} pasos {string_retornos100}')

    return q_valores

# %%
q_valores_sarsa_con_lava_negativa = sarsa() # Sarsa debe haberse modificado para que caer a la lava proporcione recompensa -1
dibuja_politica(q_valores_sarsa_con_lava_negativa)
# Out:
# Terminado episodio 0 con retorno -1 en 74 pasos
# Terminado episodio 1 con retorno -1 en 119 pasos
# Terminado episodio 2 con retorno -1 en 44 pasos
# Terminado episodio 3 con retorno -1 en 537 pasos
# Terminado episodio 4 con retorno -1 en 22 pasos
# Terminado episodio 5 con retorno -1 en 144 pasos
# Terminado episodio 6 con retorno -1 en 157 pasos
# Terminado episodio 7 con retorno -1 en 98 pasos
# Terminado episodio 8 con retorno -1 en 265 pasos
# Terminado episodio 9 con retorno -1 en 181 pasos
# Terminado episodio 10 con retorno -1 en 590 pasos
# Terminado episodio 11 con retorno -1 en 160 pasos
# Terminado episodio 12 con retorno -0.2857142857142858 en 360 pasos
# Terminado episodio 13 con retorno -5.253571428571429 en 1751 pasos
# Terminado episodio 14 con retorno -1 en 1306 pasos
# Terminado episodio 15 con retorno -1 en 1558 pasos
# Terminado episodio 16 con retorno -1 en 908 pasos
# Terminado episodio 17 con retorno -1 en 642 pasos
# Terminado episodio 18 con retorno -1 en 445 pasos
# Terminado episodio 19 con retorno -1 en 190 pasos
# Terminado episodio 20 con retorno -1 en 435 pasos
# Terminado episodio 21 con retorno -1 en 991 pasos
# Terminado episodio 22 con retorno -1 en 1142 pasos
# Terminado episodio 23 con retorno -1 en 773 pasos
# Terminado episodio 24 con retorno -1 en 1162 pasos
# Terminado episodio 25 con retorno 0.5214285714285714 en 134 pasos
# Terminado episodio 26 con retorno -0.11428571428571432 en 312 pasos
# Terminado episodio 27 con retorno -0.5571428571428572 en 436 pasos
# Terminado episodio 28 con retorno -6.746428571428572 en 2169 pasos
# Terminado episodio 29 con retorno -1 en 1056 pasos
# Terminado episodio 30 con retorno -20.085714285714285 en 5904 pasos
# Terminado episodio 31 con retorno -1 en 2698 pasos
# Terminado episodio 32 con retorno -1 en 9822 pasos
# Terminado episodio 33 con retorno -1 en 2432 pasos
# Terminado episodio 34 con retorno -3.814285714285714 en 1348 pasos
# Terminado episodio 35 con retorno -13.75 en 4130 pasos
# Terminado episodio 36 con retorno -1 en 19509 pasos
# Terminado episodio 37 con retorno -1 en 84354 pasos
# Terminado episodio 38 con retorno -1 en 553630 pasos
# Terminado episodio 39 con retorno -10366.528571428573 en 2902908 pasos
# Terminado episodio 40 con retorno -791.6535714285715 en 221943 pasos
# Terminado episodio 41 con retorno -1 en 150011 pasos
# Terminado episodio 42 con retorno -3096.253571428572 en 867231 pasos
# Terminado episodio 43 con retorno -1 en 2917740 pasos
# Terminado episodio 44 con retorno -1 en 3612722 pasos
# Terminado episodio 45 con retorno -1 en 593379 pasos
# Terminado episodio 46 con retorno -1 en 1049095 pasos
# Terminado episodio 47 con retorno -1 en 1070361 pasos
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-9-7742e604a35c> in <cell line: 0>()
# ----> 1 q_valores_sarsa_con_lava_negativa = sarsa() # Sarsa debe haberse modificado para que caer a la lava proporcione recompensa -1
#       2 dibuja_politica(q_valores_sarsa_con_lava_negativa)
#
# <ipython-input-8-da0bdf3d863e> in sarsa(num_episodios, ALPHA, EPSILON)
#      21             num_pasos += 1
#      22             # TODO - Take action A, observe R, S'
# ---> 23             obs, reward, completado, truncado, info = env.step(ACCIONES_UTILES[accion_actual])
#      24             estado_siguiente = get_estado(env)
#      25
#
# /usr/local/lib/python3.11/dist-packages/gymnasium/wrappers/common.py in step(self, action)
#     391         if not self._has_reset:
#     392             raise ResetNeeded("Cannot call env.step() before calling env.reset()")
# --> 393         return super().step(action)
#     394
#     395     def reset(
#
# /usr/local/lib/python3.11/dist-packages/gymnasium/core.py in step(self, action)
#     325     ) -> tuple[WrapperObsType, SupportsFloat, bool, bool, dict[str, Any]]:
#     326         """Uses the :meth:`step` of the :attr:`env` that can be overwritten to change the returned data."""
# --> 327         return self.env.step(action)
#     328
#     329     def reset(
#
# /usr/local/lib/python3.11/dist-packages/gymnasium/wrappers/common.py in step(self, action)
#     283             return env_step_passive_checker(self.env, action)
#     284         else:
# --> 285             return self.env.step(action)
#     286
#     287     def reset(
#
# /usr/local/lib/python3.11/dist-packages/minigrid/minigrid_env.py in step(self, action)
#     591             self.render()
#     592
# --> 593         obs = self.gen_obs()
#     594
#     595         return obs, reward, terminated, truncated, {}
#
# /usr/local/lib/python3.11/dist-packages/minigrid/minigrid_env.py in gen_obs(self)
#     637         """
#     638
# --> 639         grid, vis_mask = self.gen_obs_grid()
#     640
#     641         # Encode the partially observable view into a numpy array
#
# /usr/local/lib/python3.11/dist-packages/minigrid/minigrid_env.py in gen_obs_grid(self, agent_view_size)
#     610
#     611         for i in range(self.agent_dir + 1):
# --> 612             grid = grid.rotate_left()
#     613
#     614         # Process occluders and visibility
#
# /usr/local/lib/python3.11/dist-packages/minigrid/core/grid.py in rotate_left(self)
#     117         for i in range(self.width):
#     118             for j in range(self.height):
# --> 119                 v = self.get(i, j)
#     120                 grid.set(j, grid.height - 1 - i, v)
#     121
#
# /usr/local/lib/python3.11/dist-packages/minigrid/core/grid.py in get(self, i, j)
#      72         self.grid[j * self.width + i] = v
#      73
# ---> 74     def get(self, i: int, j: int) -> WorldObj | None:
#      75         assert 0 <= i < self.width
#      76         assert 0 <= j < self.height
#
# KeyboardInterrupt:

# %% [markdown]
# ### Q-learning
# El algoritmo Q-learning es de los más populares dentro del Aprendizaje por Refuerzo. Es muy similar a SARSA, pero tiene una importante diferencia: es *off-policy*. Si SARSA hacía las actualizaciones de $Q(S_t,A_t)$ en función de la acción $A_{t+1}$ que tomaba, Q-learning va a hacer dichas actualizaciones independientemente de la acción que finalmente tome. Por tanto, estará utilizando una política para explorar pero otra para actualizar. En concreto, Q-learning actualiza según esta fórmula:
#
# $$Q(S_t,A_t) \leftarrow Q(S_t,A_t) + \alpha [R_{t+1} + \gamma \max_aQ(S_{t+1},a) - Q(S_t,A_t)]$$
#
# Q-learning no actualiza en función de la acción que va a tomar, sino en función de la mejor acción posible. El algoritmo completo aparece descrito a continuación.
#
# ![Q-learning](https://github.com/eirasf/GCED-AA3/blob/main/lab6/img/q-learning.png?raw=1)
#
# Implementemos Q-learning mostrando los mismos mensajes a cada paso que mostrábamos con SARSA. Mantén las recompensas negativas para cuando el agente caiga en la lava.

# %%
# TODO - Implementa q_learning
#  Utiliza el mismo código que para sarsa pero cambiando la actualización
#  Recuerda mantener las recompensas negativas para cuando el agente caiga en la lava y mostrar los mensajes
def q_learning(num_episodios: int = 500, ALPHA: float = 0.1, EPSILON: float = 0.25) -> np.ndarray:
    # Inicializa los valores Q a cero con el shape adecuado
    q_valores = np.zeros((NUM_COLUMNAS, NUM_FILAS, NUM_ORIENTACIONES, NUM_ACCIONES))

    # En ultimos100retornos almacenaremos los retornos de los últimos 100 episodios
    ultimos100retornos = []
    # Haz tantos episodios como indica num_episodes
    for i in range(num_episodios):
        # Devuelve el entorno a su estado inicial
        env.reset()
        # Initialize S
        estado_actual = get_estado(env)

        retorno = 0
        num_pasos = 0
        # Loop for each step of episode (repite hasta que el episodio termine)
        completado = False
        while not completado:
            num_pasos += 1
            # Choose A from S using policy derived from Q (e.g. epsilon-greedy)
            accion_actual = get_accion_epsilon_greedy(q_valores[estado_actual.x, estado_actual.y, estado_actual.dir], EPSILON)
            # Take action A, observe R, S'
            obs, reward, completado, truncado, info = env.step(ACCIONES_UTILES[accion_actual])
            estado_siguiente = get_estado(env)

            # Añadimos la condición para penalizar caer en la lava
            if completado and reward == 0:
                reward = -1

            # Acumula la recompensa R a returns para poder imprimir el retorno del episodio
            retorno += reward

            # Q(S,A) <- Q(S,A) + ALPHA * [R + GAMMA * max_a Q(S',a) - Q(S,A)]
            q_valores[estado_actual.x, estado_actual.y, estado_actual.dir, accion_actual] += ALPHA * (reward + GAMMA * np.max(q_valores[estado_siguiente.x, estado_siguiente.y, estado_siguiente.dir]) - q_valores[estado_actual.x, estado_actual.y, estado_actual.dir, accion_actual])

            # S <- S'
            estado_actual = estado_siguiente

        # Tras terminar el episodio almacenamos el retorno en los 100 últimos...
        ultimos100retornos.append(retorno)
        string_retornos100 = ''
        if len(ultimos100retornos) == 101:  # ... y si hay ya más de 100...
            ultimos100retornos.pop(0)  # ...quitamos el más antiguo (para tener siempre 100, no más)...
            # ... y preparamos el mensaje para mostrar la media de los retornos
            string_retornos100 = f'(retorno medio de {np.mean(ultimos100retornos)} en los últimos 100 episodios)'
        # Mostramos el mensaje tras cada episodio
        print(f'Terminado episodio {i} con retorno {retorno} en {num_pasos} pasos {string_retornos100}')

    return q_valores

q_valores_q = q_learning()
dibuja_politica(q_valores_q)
# Out:
# Terminado episodio 0 con retorno -1 en 27 pasos
# Terminado episodio 1 con retorno -1 en 62 pasos
# Terminado episodio 2 con retorno -1 en 278 pasos
# Terminado episodio 3 con retorno -1 en 6 pasos
# Terminado episodio 4 con retorno -1 en 340 pasos
# Terminado episodio 5 con retorno -1 en 159 pasos
# Terminado episodio 6 con retorno -1 en 40 pasos
# Terminado episodio 7 con retorno -1 en 247 pasos
# Terminado episodio 8 con retorno -1 en 275 pasos
# Terminado episodio 9 con retorno -1 en 624 pasos
# Terminado episodio 10 con retorno -1 en 126 pasos
# Terminado episodio 11 con retorno -1 en 117 pasos
# Terminado episodio 12 con retorno -1 en 2 pasos
# Terminado episodio 13 con retorno -1 en 180 pasos
# Terminado episodio 14 con retorno -1 en 23 pasos
# Terminado episodio 15 con retorno -1 en 46 pasos
# Terminado episodio 16 con retorno -1 en 121 pasos
# Terminado episodio 17 con retorno -1 en 55 pasos
# Terminado episodio 18 con retorno -1 en 358 pasos
# Terminado episodio 19 con retorno -1 en 83 pasos
# Terminado episodio 20 con retorno -1 en 149 pasos
# Terminado episodio 21 con retorno -1 en 43 pasos
# Terminado episodio 22 con retorno -1 en 129 pasos
# Terminado episodio 23 con retorno -1 en 2 pasos
# Terminado episodio 24 con retorno -1 en 99 pasos
# Terminado episodio 25 con retorno -1 en 166 pasos
# Terminado episodio 26 con retorno -1 en 1005 pasos
# Terminado episodio 27 con retorno -1 en 80 pasos
# Terminado episodio 28 con retorno -1 en 16 pasos
# Terminado episodio 29 con retorno -1 en 21 pasos
# Terminado episodio 30 con retorno -1 en 219 pasos
# Terminado episodio 31 con retorno -1 en 634 pasos
# Terminado episodio 32 con retorno -1 en 94 pasos
# Terminado episodio 33 con retorno -1 en 61 pasos
# Terminado episodio 34 con retorno -1 en 565 pasos
# Terminado episodio 35 con retorno -1 en 144 pasos
# Terminado episodio 36 con retorno -0.8178571428571428 en 509 pasos
# Terminado episodio 37 con retorno -1 en 598 pasos
# Terminado episodio 38 con retorno -1 en 356 pasos
# Terminado episodio 39 con retorno -1 en 59 pasos
# Terminado episodio 40 con retorno -1 en 241 pasos
# Terminado episodio 41 con retorno -1 en 127 pasos
# Terminado episodio 42 con retorno -1 en 129 pasos
# Terminado episodio 43 con retorno -1 en 2381 pasos
# Terminado episodio 44 con retorno -1 en 86 pasos
# Terminado episodio 45 con retorno -1 en 76 pasos
# Terminado episodio 46 con retorno -1 en 1366 pasos
# Terminado episodio 47 con retorno -1 en 289 pasos
# Terminado episodio 48 con retorno -0.6714285714285715 en 468 pasos
# Terminado episodio 49 con retorno -1 en 892 pasos
# Terminado episodio 50 con retorno -1 en 34 pasos
# Terminado episodio 51 con retorno -1 en 50 pasos
# Terminado episodio 52 con retorno -1 en 591 pasos
# Terminado episodio 53 con retorno -1 en 841 pasos
# Terminado episodio 54 con retorno -1 en 102 pasos
# Terminado episodio 55 con retorno -1 en 399 pasos
# Terminado episodio 56 con retorno -1 en 762 pasos
# Terminado episodio 57 con retorno -1 en 140 pasos
# Terminado episodio 58 con retorno -1 en 335 pasos
# Terminado episodio 59 con retorno -1 en 38 pasos
# Terminado episodio 60 con retorno -1 en 48 pasos
# Terminado episodio 61 con retorno -1 en 575 pasos
# Terminado episodio 62 con retorno -1 en 71 pasos
# Terminado episodio 63 con retorno -1 en 221 pasos
# Terminado episodio 64 con retorno -1 en 98 pasos
# Terminado episodio 65 con retorno -1 en 204 pasos
# Terminado episodio 66 con retorno -1 en 147 pasos
# Terminado episodio 67 con retorno -1 en 185 pasos
# Terminado episodio 68 con retorno -1 en 63 pasos
# Terminado episodio 69 con retorno -1 en 58 pasos
# Terminado episodio 70 con retorno -1 en 385 pasos
# Terminado episodio 71 con retorno -1 en 209 pasos
# Terminado episodio 72 con retorno -1 en 291 pasos
# Terminado episodio 73 con retorno -1 en 251 pasos
# Terminado episodio 74 con retorno -1 en 92 pasos
# Terminado episodio 75 con retorno -1 en 54 pasos
# Terminado episodio 76 con retorno -1 en 246 pasos
# Terminado episodio 77 con retorno -1 en 10 pasos
# Terminado episodio 78 con retorno -1 en 254 pasos
# Terminado episodio 79 con retorno -1 en 77 pasos
# Terminado episodio 80 con retorno -1 en 419 pasos
# Terminado episodio 81 con retorno -1 en 472 pasos
# Terminado episodio 82 con retorno -1 en 106 pasos
# Terminado episodio 83 con retorno -1 en 397 pasos
# Terminado episodio 84 con retorno -1 en 62 pasos
# Terminado episodio 85 con retorno -1 en 2125 pasos
# Terminado episodio 86 con retorno -1 en 75 pasos
# Terminado episodio 87 con retorno -1 en 264 pasos
# Terminado episodio 88 con retorno -1 en 46 pasos
# Terminado episodio 89 con retorno -1 en 203 pasos
# Terminado episodio 90 con retorno -1 en 71 pasos
# Terminado episodio 91 con retorno -0.1607142857142858 en 325 pasos
# Terminado episodio 92 con retorno -1 en 74 pasos
# Terminado episodio 93 con retorno -1 en 1457 pasos
# Terminado episodio 94 con retorno -1 en 56 pasos
# Terminado episodio 95 con retorno -1 en 209 pasos
# Terminado episodio 96 con retorno -1 en 358 pasos
# Terminado episodio 97 con retorno -1 en 24 pasos
# Terminado episodio 98 con retorno -1 en 229 pasos
# Terminado episodio 99 con retorno -1 en 605 pasos
# Terminado episodio 100 con retorno -1 en 33 pasos (retorno medio de -0.9865 en los últimos 100 episodios)
# Terminado episodio 101 con retorno -1 en 26 pasos (retorno medio de -0.9865 en los últimos 100 episodios)
# Terminado episodio 102 con retorno -1 en 99 pasos (retorno medio de -0.9865 en los últimos 100 episodios)
# Terminado episodio 103 con retorno -1 en 141 pasos (retorno medio de -0.9865 en los últimos 100 episodios)
# Terminado episodio 104 con retorno -1 en 105 pasos (retorno medio de -0.9865 en los últimos 100 episodios)
# Terminado episodio 105 con retorno -1 en 423 pasos (retorno medio de -0.9865 en los últimos 100 episodios)
# Terminado episodio 106 con retorno -1 en 219 pasos (retorno medio de -0.9865 en los últimos 100 episodios)
# Terminado episodio 107 con retorno -1 en 89 pasos (retorno medio de -0.9865 en los últimos 100 episodios)
# Terminado episodio 108 con retorno -1 en 124 pasos (retorno medio de -0.9865 en los últimos 100 episodios)
# Terminado episodio 109 con retorno -1 en 263 pasos (retorno medio de -0.9865 en los últimos 100 episodios)
# Terminado episodio 110 con retorno -1 en 315 pasos (retorno medio de -0.9865 en los últimos 100 episodios)
# Terminado episodio 111 con retorno -1 en 52 pasos (retorno medio de -0.9865 en los últimos 100 episodios)
# Terminado episodio 112 con retorno -1 en 352 pasos (retorno medio de -0.9865 en los últimos 100 episodios)
# Terminado episodio 113 con retorno -1 en 237 pasos (retorno medio de -0.9865 en los últimos 100 episodios)
# Terminado episodio 114 con retorno -1 en 697 pasos (retorno medio de -0.9865 en los últimos 100 episodios)
# Terminado episodio 115 con retorno -1 en 133 pasos (retorno medio de -0.9865 en los últimos 100 episodios)
# Terminado episodio 116 con retorno -1 en 1503 pasos (retorno medio de -0.9865 en los últimos 100 episodios)
# Terminado episodio 117 con retorno -1 en 395 pasos (retorno medio de -0.9865 en los últimos 100 episodios)
# Terminado episodio 118 con retorno -1 en 328 pasos (retorno medio de -0.9865 en los últimos 100 episodios)
# Terminado episodio 119 con retorno -1 en 87 pasos (retorno medio de -0.9865 en los últimos 100 episodios)
# Terminado episodio 120 con retorno -1 en 111 pasos (retorno medio de -0.9865 en los últimos 100 episodios)
# Terminado episodio 121 con retorno -1 en 121 pasos (retorno medio de -0.9865 en los últimos 100 episodios)
# Terminado episodio 122 con retorno -1 en 692 pasos (retorno medio de -0.9865 en los últimos 100 episodios)
# Terminado episodio 123 con retorno -1 en 51 pasos (retorno medio de -0.9865 en los últimos 100 episodios)
# Terminado episodio 124 con retorno -1 en 256 pasos (retorno medio de -0.9865 en los últimos 100 episodios)
# Terminado episodio 125 con retorno -1 en 155 pasos (retorno medio de -0.9865 en los últimos 100 episodios)
# Terminado episodio 126 con retorno -1 en 334 pasos (retorno medio de -0.9865 en los últimos 100 episodios)
# Terminado episodio 127 con retorno -1 en 32 pasos (retorno medio de -0.9865 en los últimos 100 episodios)
# Terminado episodio 128 con retorno -1 en 231 pasos (retorno medio de -0.9865 en los últimos 100 episodios)
# Terminado episodio 129 con retorno -1 en 157 pasos (retorno medio de -0.9865 en los últimos 100 episodios)
# Terminado episodio 130 con retorno -1 en 60 pasos (retorno medio de -0.9865 en los últimos 100 episodios)
# Terminado episodio 131 con retorno -1 en 394 pasos (retorno medio de -0.9865 en los últimos 100 episodios)
# Terminado episodio 132 con retorno -1 en 145 pasos (retorno medio de -0.9865 en los últimos 100 episodios)
# Terminado episodio 133 con retorno -1 en 58 pasos (retorno medio de -0.9865 en los últimos 100 episodios)
# Terminado episodio 134 con retorno -1 en 176 pasos (retorno medio de -0.9865 en los últimos 100 episodios)
# Terminado episodio 135 con retorno -1 en 56 pasos (retorno medio de -0.9865 en los últimos 100 episodios)
# Terminado episodio 136 con retorno -1.6035714285714286 en 729 pasos (retorno medio de -0.9943571428571428 en los últimos 100 episodios)
# Terminado episodio 137 con retorno -1 en 59 pasos (retorno medio de -0.9943571428571428 en los últimos 100 episodios)
# Terminado episodio 138 con retorno -1 en 251 pasos (retorno medio de -0.9943571428571428 en los últimos 100 episodios)
# Terminado episodio 139 con retorno -1 en 121 pasos (retorno medio de -0.9943571428571428 en los últimos 100 episodios)
# Terminado episodio 140 con retorno -1 en 133 pasos (retorno medio de -0.9943571428571428 en los últimos 100 episodios)
# Terminado episodio 141 con retorno -1 en 252 pasos (retorno medio de -0.9943571428571428 en los últimos 100 episodios)
# Terminado episodio 142 con retorno -1 en 25 pasos (retorno medio de -0.9943571428571428 en los últimos 100 episodios)
# Terminado episodio 143 con retorno -1 en 48 pasos (retorno medio de -0.9943571428571428 en los últimos 100 episodios)
# Terminado episodio 144 con retorno -1 en 138 pasos (retorno medio de -0.9943571428571428 en los últimos 100 episodios)
# Terminado episodio 145 con retorno -1 en 169 pasos (retorno medio de -0.9943571428571428 en los últimos 100 episodios)
# Terminado episodio 146 con retorno -1 en 167 pasos (retorno medio de -0.9943571428571428 en los últimos 100 episodios)
# Terminado episodio
pasos (retorno medio de -1.0903571428571428 en los últimos 100 episodios)
# Terminado episodio 234 con retorno -1 en 100 pasos (retorno medio de -1.0903571428571428 en los últimos 100 episodios)
# Terminado episodio 235 con retorno -1 en 357 pasos (retorno medio de -1.090357142857143 en los últimos 100 episodios)
# Terminado episodio 236 con retorno -1 en 100 pasos (retorno medio de -1.0843214285714284 en los últimos 100 episodios)
# Terminado episodio 237 con retorno -1 en 154 pasos (retorno medio de -1.0843214285714284 en los últimos 100 episodios)
# Terminado episodio 238 con retorno -1 en 49 pasos (retorno medio de -1.0843214285714284 en los últimos 100 episodios)
# Terminado episodio 239 con retorno -1 en 109 pasos (retorno medio de -1.0843214285714287 en los últimos 100 episodios)
# Terminado episodio 240 con retorno -1 en 90 pasos (retorno medio de -1.0843214285714284 en los últimos 100 episodios)
# Terminado episodio 241 con retorno -1 en 528 pasos (retorno medio de -1.0843214285714284 en los últimos 100 episodios)
# Terminado episodio 242 con retorno -1 en 278 pasos (retorno medio de -1.0843214285714284 en los últimos 100 episodios)
# Terminado episodio 243 con retorno -1.5964285714285715 en 727 pasos (retorno medio de -1.0902857142857143 en los últimos 100 episodios)
# Terminado episodio 244 con retorno -1 en 9 pasos (retorno medio de -1.0902857142857143 en los últimos 100 episodios)
# Terminado episodio 245 con retorno -1 en 273 pasos (retorno medio de -1.0902857142857143 en los últimos 100 episodios)
# Terminado episodio 246 con retorno -1 en 60 pasos (retorno medio de -1.0902857142857143 en los últimos 100 episodios)
# Terminado episodio 247 con retorno -1 en 100 pasos (retorno medio de -1.0902857142857143 en los últimos 100 episodios)
# Terminado episodio 248 con retorno -1 en 121 pasos (retorno medio de -1.0902857142857143 en los últimos 100 episodios)
# Terminado episodio 249 con retorno -1 en 176 pasos (retorno medio de -1.0902857142857143 en los últimos 100 episodios)
# Terminado episodio 250 con retorno -1 en 20 pasos (retorno medio de -1.0902857142857143 en los últimos 100 episodios)
# Terminado episodio 251 con retorno -1 en 389 pasos (retorno medio de -1.0902857142857143 en los últimos 100 episodios)
# Terminado episodio 252 con retorno -1 en 637 pasos (retorno medio de -1.0902857142857143 en los últimos 100 episodios)
# Terminado episodio 253 con retorno -1 en 28 pasos (retorno medio de -1.0902857142857143 en los últimos 100 episodios)
# Terminado episodio 254 con retorno -1 en 460 pasos (retorno medio de -1.0902857142857143 en los últimos 100 episodios)
# Terminado episodio 255 con retorno -1 en 41 pasos (retorno medio de -1.0902857142857143 en los últimos 100 episodios)
# Terminado episodio 256 con retorno -1.560714285714286 en 717 pasos (retorno medio de -1.0958928571428572 en los últimos 100 episodios)
# Terminado episodio 257 con retorno -1 en 81 pasos (retorno medio de -1.095892857142857 en los últimos 100 episodios)
# Terminado episodio 258 con retorno -1 en 138 pasos (retorno medio de -1.095892857142857 en los últimos 100 episodios)
# Terminado episodio 259 con retorno -1 en 45 pasos (retorno medio de -1.0958928571428572 en los últimos 100 episodios)
# Terminado episodio 260 con retorno -1 en 240 pasos (retorno medio de -1.0958928571428572 en los últimos 100 episodios)
# Terminado episodio 261 con retorno -1 en 68 pasos (retorno medio de -1.095892857142857 en los últimos 100 episodios)
# Terminado episodio 262 con retorno -1 en 68 pasos (retorno medio de -1.095892857142857 en los últimos 100 episodios)
# Terminado episodio 263 con retorno -1 en 27 pasos (retorno medio de -1.0958928571428572 en los últimos 100 episodios)
# Terminado episodio 264 con retorno -1 en 743 pasos (retorno medio de -1.0958928571428572 en los últimos 100 episodios)
# Terminado episodio 265 con retorno -1 en 47 pasos (retorno medio de -1.095892857142857 en los últimos 100 episodios)
# Terminado episodio 266 con retorno -1 en 203 pasos (retorno medio de -1.095892857142857 en los últimos 100 episodios)
# Terminado episodio 267 con retorno -1 en 50 pasos (retorno medio de -1.0958928571428572 en los últimos 100 episodios)
# Terminado episodio 268 con retorno -1 en 73 pasos (retorno medio de -1.0958928571428572 en los últimos 100 episodios)
# Terminado episodio 269 con retorno -1 en 189 pasos (retorno medio de -1.095892857142857 en los últimos 100 episodios)
# Terminado episodio 270 con retorno -1 en 107 pasos (retorno medio de -1.095892857142857 en los últimos 100 episodios)
# Terminado episodio 271 con retorno -1 en 167 pasos (retorno medio de -1.0958928571428572 en los últimos 100 episodios)
# Terminado episodio 272 con retorno -1 en 347 pasos (retorno medio de -1.0958928571428572 en los últimos 100 episodios)
# Terminado episodio 273 con retorno -0.9892857142857145 en 557 pasos (retorno medio de -1.0957857142857141 en los últimos 100 episodios)
# Terminado episodio 274 con retorno -1 en 309 pasos (retorno medio de -1.0957857142857141 en los últimos 100 episodios)
# Terminado episodio 275 con retorno -1 en 25 pasos (retorno medio de -1.0957857142857144 en los últimos 100 episodios)
# Terminado episodio 276 con retorno -1 en 63 pasos (retorno medio de -1.0957857142857144 en los últimos 100 episodios)
# Terminado episodio 277 con retorno -1 en 115 pasos (retorno medio de -1.0957857142857141 en los últimos 100 episodios)
# Terminado episodio 278 con retorno -1 en 10 pasos (retorno medio de -1.0957857142857141 en los últimos 100 episodios)
# Terminado episodio 279 con retorno -1 en 110 pasos (retorno medio de -1.0957857142857144 en los últimos 100 episodios)
# Terminado episodio 280 con retorno -1 en 8 pasos (retorno medio de -1.0957857142857144 en los últimos 100 episodios)
# Terminado episodio 281 con retorno -1 en 253 pasos (retorno medio de -1.0957857142857141 en los últimos 100 episodios)
# Terminado episodio 282 con retorno -1 en 114 pasos (retorno medio de -1.0957857142857141 en los últimos 100 episodios)
# Terminado episodio 283 con retorno -1 en 157 pasos (retorno medio de -1.0957857142857144 en los últimos 100 episodios)
# Terminado episodio 284 con retorno -1 en 315 pasos (retorno medio de -1.0957857142857144 en los últimos 100 episodios)
# Terminado episodio 285 con retorno -1 en 300 pasos (retorno medio de -1.0957857142857141 en los últimos 100 episodios)
# Terminado episodio 286 con retorno -1 en 160 pasos (retorno medio de -1.0957857142857141 en los últimos 100 episodios)
# Terminado episodio 287 con retorno -1 en 61 pasos (retorno medio de -1.0957857142857144 en los últimos 100 episodios)
# Terminado episodio 288 con retorno -1 en 22 pasos (retorno medio de -1.0957857142857144 en los últimos 100 episodios)
# Terminado episodio 289 con retorno -1 en 33 pasos (retorno medio de -1.0957857142857141 en los últimos 100 episodios)
# Terminado episodio 290 con retorno -1 en 329 pasos (retorno medio de -1.0957857142857141 en los últimos 100 episodios)
# Terminado episodio 291 con retorno -1 en 510 pasos (retorno medio de -1.0957857142857144 en los últimos 100 episodios)
# Terminado episodio 292 con retorno -1 en 38 pasos (retorno medio de -1.0957857142857144 en los últimos 100 episodios)
# Terminado episodio 293 con retorno -1 en 80 pasos (retorno medio de -1.0957857142857141 en los últimos 100 episodios)
# Terminado episodio 294 con retorno -1 en 37 pasos (retorno medio de -1.0957857142857141 en los últimos 100 episodios)
# Terminado episodio 295 con retorno -1 en 199 pasos (retorno medio de -1.0957857142857144 en los últimos 100 episodios)
# Terminado episodio 296 con retorno -1 en 89 pasos (retorno medio de -1.0957857142857144 en los últimos 100 episodios)
# Terminado episodio 297 con retorno -1 en 210 pasos (retorno medio de -1.0957857142857141 en los últimos 100 episodios)
# Terminado episodio 298 con retorno -1 en 61 pasos (retorno medio de -1.0957857142857141 en los últimos 100 episodios)
# Terminado episodio 299 con retorno -1 en 49 pasos (retorno medio de -1.0957857142857144 en los últimos 100 episodios)
# Terminado episodio 300 con retorno -1 en 12 pasos (retorno medio de -1.0898214285714287 en los últimos 100 episodios)
# Terminado episodio 301 con retorno -1.0214285714285714 en 566 pasos (retorno medio de -1.0900357142857144 en los últimos 100 episodios)
# Terminado episodio 302 con retorno -1 en 59 pasos (retorno medio de -1.0900357142857144 en los últimos 100 episodios)
# Terminado episodio 303 con retorno -1 en 61 pasos (retorno medio de -1.0900357142857144 en los últimos 100 episodios)
# Terminado episodio 304 con retorno -1 en 111 pasos (retorno medio de -1.0900357142857144 en los últimos 100 episodios)
# Terminado episodio 305 con retorno -1 en 208 pasos (retorno medio de -1.0900357142857144 en los últimos 100 episodios)
# Terminado episodio 306 con retorno -1 en 316 pasos (retorno medio de -1.0900357142857144 en los últimos 100 episodios)
# Terminado episodio 307 con retorno -1 en 163 pasos (retorno medio de -1.0900357142857144 en los últimos 100 episodios)
# Terminado episodio 308 con retorno -1 en 92 pasos (retorno medio de -1.0900357142857144 en los últimos 100 episodios)
# Terminado episodio 309 con retorno -1 en 298 pasos (retorno medio de -1.0900357142857144 en los últimos 100 episodios)
# Terminado episodio 310 con retorno -1 en 50 pasos (retorno medio de -1.0900357142857144 en los últimos 100 episodios)
# Terminado episodio 311 con retorno -1 en 62 pasos (retorno medio de -1.0900357142857144 en los últimos 100 episodios)
# Terminado episodio 312 con retorno -1 en 35 pasos (retorno medio de -1.0900357142857144 en los últimos 100 episodios)
# Terminado episodio 313 con retorno -1 en 136 pasos (retorno medio de -1.04675 en los últimos 100 episodios)
# Terminado episodio 314 con retorno -1 en 525 pasos (retorno medio de -1.04675 en los últimos 100 episodios)
# Terminado episodio 315 con retorno -1 en 65 pasos (retorno medio de -1.0116785714285714 en los últimos 100 episodios)
# Terminado episodio 316 con retorno -1 en 335 pasos (retorno medio de -1.0116785714285714 en los últimos 100 episodios)
# Terminado episodio 317 con retorno -1 en 77 pasos (retorno medio de -1.0116785714285714 en los últimos 100 episodios)
# Terminado episodio 318 con retorno -1 en 511 pasos (retorno medio de -1.0116785714285714 en los últimos 100 episodios)
# Terminado episodio 319 con retorno -1 en 75 pasos (retorno medio de -1.0116785714285714 en los últimos 100 episodios)
# Terminado episodio 320 con retorno -1 en 128 pasos (retorno medio de -1.0116785714285714 en los últimos 100 episodios)
# Terminado episodio 321 con retorno -1 en 21 pasos (retorno medio de -1.0116785714285714 en los últimos 100 episodios)
# Terminado episodio 322 con retorno -1 en 8 pasos (retorno medio de -1.0116785714285714 en los últimos 100 episodios)
# Terminado episodio 323 con retorno -1 en 42 pasos (retorno medio de -1.0116785714285714 en los últimos 100 episodios)
# Terminado episodio 324 con retorno -1 en 296 pasos (retorno medio de -1.0116785714285714 en los últimos 100 episodios)
# Terminado episodio 325 con retorno -1 en 415 pasos (retorno medio de -1.0116785714285714 en los últimos 100 episodios)
# Terminado episodio 326 con retorno -1 en 127 pasos (retorno medio de -1.0116785714285714 en los últimos 100 episodios)
# Terminado episodio 327 con retorno -1 en 493 pasos (retorno medio de -1.0116785714285714 en los últimos 100 episodios)
# Terminado episodio 328 con retorno -1 en 139 pasos (retorno medio de -1.0116785714285714 en los últimos 100 episodios)
# Terminado episodio 329 con retorno -1 en 212 pasos (retorno medio de -1.0116785714285714 en los últimos 100 episodios)
# Terminado episodio 330 con retorno -1 en 60 pasos (retorno medio de -1.0116785714285714 en los últimos 100 episodios)
# Terminado episodio 331 con retorno -1 en 2 pasos (retorno medio de -1.0116785714285714 en los últimos 100 episodios)
# Terminado episodio 332 con retorno -1 en 309 pasos (retorno medio de -1.0116785714285714 en los últimos 100 episodios)
# Terminado episodio 333 con retorno -1 en 99 pasos (retorno medio de -1.0116785714285714 en los últimos 100 episodios)
# Terminado episodio 334 con retorno -2.210714285714286 en 899 pasos (retorno medio de -1.0237857142857143 en los últimos 100 episodios)
# Terminado episodio 335 con retorno -1 en 15 pasos (retorno medio de -1.0237857142857143 en los últimos 100 episodios)
# Terminado episodio 336 con retorno -1 en 392 pasos (retorno medio de -1.0237857142857143 en los últimos 100 episodios)
# Terminado episodio 337 con retorno -1 en 98 pasos (retorno medio de -1.0237857142857143 en los últimos 100 episodios)
# Terminado episodio 338 con retorno -1 en 23 pasos (retorno medio de -1.0237857142857143 en los últimos 100 episodios)
# Terminado episodio 339 con retorno -1 en 353 pasos (retorno medio de -1.0237857142857143 en los últimos 100 episodios)
# Terminado episodio 340 con retorno -1 en 615 pasos (retorno medio de -1.0237857142857143 en los últimos 100 episodios)
# Terminado episodio 341 con retorno -1 en 422 pasos (retorno medio de -1.0237857142857143 en los últimos 100 episodios)
# Terminado episodio 342 con retorno -1 en 33 pasos (retorno medio de -1.0237857142857143 en los últimos 100 episodios)
# Terminado episodio 343 con retorno -1.0392857142857141 en 571 pasos (retorno medio de -1.0182142857142857 en los últimos 100 episodios)
# Terminado episodio 344 con retorno -1 en 549 pasos (retorno medio de -1.0182142857142857 en los últimos 100 episodios)
# Terminado episodio 345 con retorno -1 en 37 pasos (retorno medio de -1.0182142857142857 en los últimos 100 episodios)
# Terminado episodio 346 con retorno -1 en 189 pasos (retorno medio de -1.0182142857142857 en los últimos 100 episodios)
# Terminado episodio 347 con retorno -1 en 908 pasos (retorno medio de -1.0182142857142857 en los últimos 100 episodios)
# Terminado episodio 348 con retorno -1 en 78 pasos (retorno medio de -1.0182142857142857 en los últimos 100 episodios)
# Terminado episodio 349 con retorno -0.625 en 455 pasos (retorno medio de -1.0144642857142856 en los últimos 100 episodios)
# Terminado episodio 350 con retorno -1 en 208 pasos (retorno medio de -1.0144642857142858 en los últimos 100 episodios)
# Terminado episodio 351 con retorno -1 en 73 pasos (retorno medio de -1.0144642857142856 en los últimos 100 episodios)
# Terminado episodio 352 con retorno -1 en 2012 pasos (retorno medio de -1.0144642857142856 en los últimos 100 episodios)
# Terminado episodio 353 con retorno -1 en 148 pasos (retorno medio de -1.0144642857142856 en los últimos 100 episodios)
# Terminado episodio 354 con retorno -1 en 87 pasos (retorno medio de -1.0144642857142858 en los últimos 100 episodios)
# Terminado episodio 355 con retorno -1 en 138 pasos (retorno medio de -1.0144642857142856 en los últimos 100 episodios)
# Terminado episodio 356 con retorno -1 en 118 pasos (retorno medio de -1.008857142857143 en los últimos 100 episodios)
# Terminado episodio
pasos (retorno medio de -0.99375 en los últimos 100 episodios)
# Terminado episodio 442 con retorno -1 en 68 pasos (retorno medio de -0.99375 en los últimos 100 episodios)
# Terminado episodio 443 con retorno -1 en 135 pasos (retorno medio de -0.9933571428571429 en los últimos 100 episodios)
# Terminado episodio 444 con retorno -1 en 43 pasos (retorno medio de -0.9933571428571429 en los últimos 100 episodios)
# Terminado episodio 445 con retorno -1 en 330 pasos (retorno medio de -0.9933571428571429 en los últimos 100 episodios)
# Terminado episodio 446 con retorno -1 en 78 pasos (retorno medio de -0.9933571428571429 en los últimos 100 episodios)
# Terminado episodio 447 con retorno -1 en 34 pasos (retorno medio de -0.9933571428571429 en los últimos 100 episodios)
# Terminado episodio 448 con retorno -1 en 49 pasos (retorno medio de -0.9933571428571429 en los últimos 100 episodios)
# Terminado episodio 449 con retorno -1 en 631 pasos (retorno medio de -0.9971071428571429 en los últimos 100 episodios)
# Terminado episodio 450 con retorno -1 en 22 pasos (retorno medio de -0.9971071428571429 en los últimos 100 episodios)
# Terminado episodio 451 con retorno -1 en 6 pasos (retorno medio de -0.9971071428571429 en los últimos 100 episodios)
# Terminado episodio 452 con retorno -1 en 80 pasos (retorno medio de -0.9971071428571429 en los últimos 100 episodios)
# Terminado episodio 453 con retorno -1 en 84 pasos (retorno medio de -0.9971071428571429 en los últimos 100 episodios)
# Terminado episodio 454 con retorno -1 en 34 pasos (retorno medio de -0.9971071428571429 en los últimos 100 episodios)
# Terminado episodio 455 con retorno -1 en 121 pasos (retorno medio de -0.9971071428571429 en los últimos 100 episodios)
# Terminado episodio 456 con retorno -1 en 87 pasos (retorno medio de -0.9971071428571429 en los últimos 100 episodios)
# Terminado episodio 457 con retorno -1 en 197 pasos (retorno medio de -0.9971071428571429 en los últimos 100 episodios)
# Terminado episodio 458 con retorno -1 en 28 pasos (retorno medio de -0.9971071428571429 en los últimos 100 episodios)
# Terminado episodio 459 con retorno -1 en 389 pasos (retorno medio de -0.9971071428571429 en los últimos 100 episodios)
# Terminado episodio 460 con retorno -1 en 194 pasos (retorno medio de -0.9971071428571429 en los últimos 100 episodios)
# Terminado episodio 461 con retorno -1 en 156 pasos (retorno medio de -0.9971071428571429 en los últimos 100 episodios)
# Terminado episodio 462 con retorno -1 en 750 pasos (retorno medio de -0.9971071428571429 en los últimos 100 episodios)
# Terminado episodio 463 con retorno -1 en 176 pasos (retorno medio de -0.9971071428571429 en los últimos 100 episodios)
# Terminado episodio 464 con retorno -1 en 62 pasos (retorno medio de -0.9971071428571429 en los últimos 100 episodios)
# Terminado episodio 465 con retorno -1 en 10 pasos (retorno medio de -0.9971071428571429 en los últimos 100 episodios)
# Terminado episodio 466 con retorno -1 en 483 pasos (retorno medio de -0.9971071428571429 en los últimos 100 episodios)
# Terminado episodio 467 con retorno -1 en 54 pasos (retorno medio de -0.9971071428571429 en los últimos 100 episodios)
# Terminado episodio 468 con retorno -1 en 300 pasos (retorno medio de -0.9971071428571429 en los últimos 100 episodios)
# Terminado episodio 469 con retorno -1 en 51 pasos (retorno medio de -0.9971071428571429 en los últimos 100 episodios)
# Terminado episodio 470 con retorno -1 en 1001 pasos (retorno medio de -0.9971071428571429 en los últimos 100 episodios)
# Terminado episodio 471 con retorno -1 en 6 pasos (retorno medio de -0.9971071428571429 en los últimos 100 episodios)
# Terminado episodio 472 con retorno -1 en 82 pasos (retorno medio de -0.9971071428571429 en los últimos 100 episodios)
# Terminado episodio 473 con retorno -1 en 221 pasos (retorno medio de -0.9971071428571429 en los últimos 100 episodios)
# Terminado episodio 474 con retorno -1 en 36 pasos (retorno medio de -0.9971071428571429 en los últimos 100 episodios)
# Terminado episodio 475 con retorno -1 en 12 pasos (retorno medio de -0.9971071428571429 en los últimos 100 episodios)
# Terminado episodio 476 con retorno -1 en 129 pasos (retorno medio de -0.9971071428571429 en los últimos 100 episodios)
# Terminado episodio 477 con retorno -1 en 85 pasos (retorno medio de -0.9971071428571429 en los últimos 100 episodios)
# Terminado episodio 478 con retorno -1 en 83 pasos (retorno medio de -0.9971071428571429 en los últimos 100 episodios)
# Terminado episodio 479 con retorno -1 en 397 pasos (retorno medio de -0.9971071428571429 en los últimos 100 episodios)
# Terminado episodio 480 con retorno -1 en 158 pasos (retorno medio de -0.9971071428571429 en los últimos 100 episodios)
# Terminado episodio 481 con retorno -1 en 267 pasos (retorno medio de -0.9971071428571429 en los últimos 100 episodios)
# Terminado episodio 482 con retorno -1 en 331 pasos (retorno medio de -0.9971071428571429 en los últimos 100 episodios)
# Terminado episodio 483 con retorno -1 en 20 pasos (retorno medio de -0.9971071428571429 en los últimos 100 episodios)
# Terminado episodio 484 con retorno -1 en 86 pasos (retorno medio de -0.9971071428571429 en los últimos 100 episodios)
# Terminado episodio 485 con retorno -1 en 882 pasos (retorno medio de -0.9971071428571429 en los últimos 100 episodios)
# Terminado episodio 486 con retorno -1 en 33 pasos (retorno medio de -0.9971071428571429 en los últimos 100 episodios)
# Terminado episodio 487 con retorno -1 en 111 pasos (retorno medio de -0.9971071428571429 en los últimos 100 episodios)
# Terminado episodio 488 con retorno -1 en 296 pasos (retorno medio de -0.9971071428571429 en los últimos 100 episodios)
# Terminado episodio 489 con retorno -1 en 80 pasos (retorno medio de -0.9971071428571429 en los últimos 100 episodios)
# Terminado episodio 490 con retorno -1 en 71 pasos (retorno medio de -0.9971071428571429 en los últimos 100 episodios)
# Terminado episodio 491 con retorno -1 en 178 pasos (retorno medio de -0.9971071428571429 en los últimos 100 episodios)
# Terminado episodio 492 con retorno -0.75 en 490 pasos (retorno medio de -0.9946071428571429 en los últimos 100 episodios)
# Terminado episodio 493 con retorno -1 en 502 pasos (retorno medio de -0.9946071428571429 en los últimos 100 episodios)
# Terminado episodio 494 con retorno -1 en 61 pasos (retorno medio de -0.9946071428571429 en los últimos 100 episodios)
# Terminado episodio 495 con retorno -1 en 141 pasos (retorno medio de -0.9946071428571429 en los últimos 100 episodios)
# Terminado episodio 496 con retorno -1 en 99 pasos (retorno medio de -0.9946071428571429 en los últimos 100 episodios)
# Terminado episodio 497 con retorno -1 en 444 pasos (retorno medio de -0.9946071428571429 en los últimos 100 episodios)
# Terminado episodio 498 con retorno -1 en 171 pasos (retorno medio de -0.9946071428571429 en los últimos 100 episodios)
# Terminado episodio 499 con retorno -1 en 416 pasos (retorno medio de -0.9946071428571429 en los últimos 100 episodios)
# ⮕⮕🟧🟧🟧⮕🟥
# ⮕⮕🟧🟧🟧⮕⮕
# ⮕⮕⮕⮕⮕⮕⮕
# ⮕⮕⮕⮕⮕⮕⮕
# ⮕⮕⮕⮕⮕⮕⮕

# %% [markdown]
# ### Comparativa SARSA vs Q-Learning
# Compara los resultados obtenidos por ambos algoritmos. Deberías observar lo siguiente:
#   - La política obtenida por SARSA es más conservadora (no quiere estar cerca de la lava), mientras que la de Q-learning es más optimista (no le importa estar cerca de la lava; confía en su política).
#   - Por tanto, los episodios de Q-learning son más cortos que los de SARSA.
#   - Sin embargo, al seguir una política $\epsilon$-greedy, estar en una casilla contigua a la lava desemboca en una recompensa de -1 (caer a la lava) un $\frac{\epsilon}{4}$ de las veces, por lo que el retorno medio de Q-learning es más bajo.
#
# Completa la siguiente celda para comprobarlo.

# %%
def comprueba_politica_derivada(q_values: np.ndarray, epsilon: float) -> None:
    env.reset()
    # TODO - Escribe un bucle que simule un episodio completo siguiendo una política COMPLETAMENTE GREEDY respecto a q_values
    # y muestra su duración y su retorno

    # Inicializamos el entorno y obtenemos el estado inicial
    estado_actual = get_estado(env)
    retorno = 0
    contador = 0
    completado = False

    # Bucle principal para simular un episodio con política greedy
    while not completado:
        contador += 1  # Incrementamos el contador de pasos
        # Elegimos la acción con el mayor valor Q (política greedy)
        accion_actual = np.argmax(q_values[estado_actual.x, estado_actual.y, estado_actual.dir])
        # Realizamos un paso en el entorno con la acción elegida
        obs, reward, completado, truncado, info = env.step(ACCIONES_UTILES[accion_actual])
        # Actualizamos el estado actual
        estado_actual = get_estado(env)
        # Acumulamos la recompensa
        retorno += reward

    # Imprimimos la duración y el retorno del episodio
    print(f'La política greedy hace un episodio de {contador} pasos con un retorno de {retorno}')

    env.reset()
    # TODO - Escribe otro bucle que simule 500 episodios siguiendo una política epsilon-greedy respecto a q_values
    # y muestra su duración media y su retorno medio

    duraciones = []  # Lista para almacenar las duraciones de los episodios
    retornos = []  # Lista para almacenar los retornos de los episodios

    # Bucle principal para simular 500 episodios con política epsilon-greedy
    for _ in range(500):
        # Inicializamos el entorno y obtenemos el estado inicial
        estado_actual = get_estado(env)
        retorno = 0
        contador = 0
        completado = False

        # Bucle interno para simular un episodio
        while not completado:
            contador += 1  # Incrementamos el contador de pasos
            # Elegimos la acción con la política epsilon-greedy
            accion_actual = get_accion_epsilon_greedy(q_values[estado_actual.x, estado_actual.y, estado_actual.dir], epsilon)
            # Realizamos un paso en el entorno con la acción elegida
            obs, reward, completado, truncado, info = env.step(ACCIONES_UTILES[accion_actual])
            # Actualizamos el estado actual
            estado_actual = get_estado(env)
            # Acumulamos la recompensa
            retorno += reward

        # Almacenamos la duración y el retorno del episodio
        duraciones.append(contador)
        retornos.append(retorno)

    # Imprimimos la duración media y el retorno medio de los 500 episodios
    print(f'La política epsilon-greedy hace episodios de {np.mean(duraciones)} pasos de media con un retorno de {np.mean(retornos)} de media')

print('SARSA')
q_valores_sarsa_con_lava_negativa = sarsa()
comprueba_politica_derivada(q_valores_sarsa_con_lava_negativa, 0.25)
dibuja_politica(q_valores_sarsa_con_lava_negativa)
print('\nQ-LEARNING')
comprueba_politica_derivada(q_valores_q, 0.25)
dibuja_politica(q_valores_q)
# Out:
# SARSA
# Terminado episodio 0 con retorno -1 en 738 pasos
# Terminado episodio 1 con retorno -1 en 307 pasos
# Terminado episodio 2 con retorno -1 en 145 pasos
# Terminado episodio 3 con retorno -1 en 148 pasos
# Terminado episodio 4 con retorno -1 en 451 pasos
# Terminado episodio 5 con retorno -1 en 125 pasos
# Terminado episodio 6 con retorno -1 en 42 pasos
# Terminado episodio 7 con retorno -1 en 94 pasos
# Terminado episodio 8 con retorno -1 en 322 pasos
# Terminado episodio 9 con retorno -1 en 591 pasos
# Terminado episodio 10 con retorno -1 en 133 pasos
# Terminado episodio 11 con retorno -1 en 1112 pasos
# Terminado episodio 12 con retorno -1 en 1840 pasos
# Terminado episodio 13 con retorno -1 en 220 pasos
# Terminado episodio 14 con retorno -1 en 590 pasos
# Terminado episodio 15 con retorno -1 en 37 pasos
# Terminado episodio 16 con retorno -0.8821428571428573 en 527 pasos
# Terminado episodio 17 con retorno -1 en 335 pasos
# Terminado episodio 18 con retorno -1 en 871 pasos
# Terminado episodio 19 con retorno -1 en 2661 pasos
# Terminado episodio 20 con retorno -1 en 311 pasos
# Terminado episodio 21 con retorno -1 en 80 pasos
# Terminado episodio 22 con retorno 0.25357142857142856 en 209 pasos
# Terminado episodio 23 con retorno -2.914285714285714 en 1096 pasos
# Terminado episodio 24 con retorno -1.0714285714285712 en 580 pasos
# Terminado episodio 25 con retorno -4.825 en 1631 pasos
# Terminado episodio 26 con retorno -1 en 316 pasos
# Terminado episodio 27 con retorno -1 en 46514 pasos
# Terminado episodio 28 con retorno -20.07857142857143 en 5902 pasos
# Terminado episodio 29 con retorno -36.02857142857143 en 10368 pasos
# Terminado episodio 30 con retorno -1 en 11913 pasos
# Terminado episodio 31 con retorno -1 en 2788806 pasos
# Terminado episodio 32 con retorno -2845.2214285714285 en 796942 pasos
# Terminado episodio 33 con retorno -1 en 19823063 pasos
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-12-527e28a428bc> in <cell line: 0>()
#      60
#      61 print('SARSA')
# ---> 62 q_valores_sarsa_con_lava_negativa = sarsa()
#      63 comprueba_politica_derivada(q_valores_sarsa_con_lava_negativa, 0.25)
#      64 dibuja_politica(q_valores_sarsa_con_lava_negativa)
#
# <ipython-input-8-da0bdf3d863e> in sarsa(num_episodios, ALPHA, EPSILON)
#      21             num_pasos += 1
#      22             # TODO - Take action A, observe R, S'
# ---> 23             obs, reward, completado, truncado, info = env.step(ACCIONES_UTILES[accion_actual])
#      24             estado_siguiente = get_estado(env)
#      25
#
# /usr/local/lib/python3.11/dist-packages/gymnasium/wrappers/common.py in step(self, action)
#     391         if not self._has_reset:
#     392             raise ResetNeeded("Cannot call env.step() before calling env.reset()")
# --> 393         return super().step(action)
#     394
#     395     def reset(
#
# /usr/local/lib/python3.11/dist-packages/gymnasium/core.py in step(self, action)
#     325     ) -> tuple[WrapperObsType, SupportsFloat, bool, bool, dict[str, Any]]:
#     326         """Uses the :meth:`step` of the :attr:`env` that can be overwritten to change the returned data."""
# --> 327         return self.env.step(action)
#     328
#     329     def reset(
#
# /usr/local/lib/python3.11/dist-packages/gymnasium/wrappers/common.py in step(self, action)
#     283             return env_step_passive_checker(self.env, action)
#     284         else:
# --> 285             return self.env.step(action)
#     286
#     287     def reset(
#
# /usr/local/lib/python3.11/dist-packages/minigrid/minigrid_env.py in step(self, action)
#     591             self.render()
#     592
# --> 593         obs = self.gen_obs()
#     594
#     595         return obs, reward, terminated, truncated, {}
#
# /usr/local/lib/python3.11/dist-packages/minigrid/minigrid_env.py in gen_obs(self)
#     637         """
#     638
# --> 639         grid, vis_mask = self.gen_obs_grid()
#     640
#     641         # Encode the partially observable view into a numpy array
#
# /usr/local/lib/python3.11/dist-packages/minigrid/minigrid_env.py in gen_obs_grid(self, agent_view_size)
#     607         agent_view_size = agent_view_size or self.agent_view_size
#     608
# --> 609         grid = self.grid.slice(topX, topY, agent_view_size, agent_view_size)
#     610
#     611         for i in range(self.agent_dir + 1):
#
# /usr/local/lib/python3.11/dist-packages/minigrid/core/grid.py in slice(self, topX, topY, width, height)
#     139                     v = Wall()
#     140
# --> 141                 grid.set(i, j, v)
#     142
#     143         return grid
#
# KeyboardInterrupt:
